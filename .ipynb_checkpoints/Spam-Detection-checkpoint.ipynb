# %% [markdown]
# # Spam Detection Project

# %% [markdown]
# CMPE 346 Final Project, Ibrahim Ethem Karalı, 115200058

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import AdaBoostClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.neural_network import MLPClassifier
from sklearn.svm import SVC
from wordcloud import WordCloud
from future.utils import iteritems
from builtins import range

# %% [markdown]
# ### Read and format the data

# %%
# read the data from spam.csv with this encoding to fit
data_frame = pd.read_csv('spam.csv', encoding='ISO-8859-1')

# remove unnecessary columns
data_frame = data_frame.drop(['Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'], axis=1)

# change the column names
data_frame.columns = ["label", "message"]

# %%
data_frame['b_label'] = data_frame['label'].map({'ham': 0, 'spam': 1})
Y = data_frame['b_label'].values

# %%
data_frame_train, data_frame_test, Ytrain, Ytest = train_test_split(data_frame['message'], Y, test_size=0.3)

# %% [markdown]
# #### Transform the data

# %% [markdown]
# Transform the data with TF-IDF Vectorizer for featuring vectors to use as input to estimator. It also removes the stop words.

# %%
tfidf = TfidfVectorizer(decode_error='ignore')
Xtrain = tfidf.fit_transform(data_frame_train)
Xtest = tfidf.transform(data_frame_test)

# %%
def visualize(label):
    words = ''
    for message in data_frame[data_frame['label'] == label]['message']:
        message = message.lower()
        words += message + ' '
    wordcloud = WordCloud(width=800, height=400).generate(words)
    plt.imshow(wordcloud)
    plt.axis('off')
    plt.show()

# %% [markdown]
# Visualization of the most common words in the spam messages

# %%
visualize('spam')

# %% [markdown]
# Visualization of the most common words in the ham messages

# %%
visualize('ham')

# %% [markdown]
# A function for reporting the wrong predictions which are spams that are predicted as ham, and hams that are predicted as spams.

# %%
def report_wrong_predictions(prediction_label):
    sneaky_spam = data_frame[(data_frame[prediction_label] == 0) & (data_frame['b_label'] == 1)]['message']
    print('Numbers of spams predicted as ham is ', sneaky_spam.count())
    print('\n')
    for msg in sneaky_spam[:3]:
        print(msg)
    not_actually_spam = data_frame[(data_frame[prediction_label] == 1) & (data_frame['b_label'] == 0)]['message']
    print('\n')
    print('Numbers of ham messages predicted as spam is ', not_actually_spam.count())
    print('\n')
    for msg in not_actually_spam[:3]:
        print(msg)

# %% [markdown]
# ### Multinominal Naive Bayes algorithm

# %%
NB_model = MultinomialNB()
NB_model.fit(Xtrain, Ytrain)
print('Naive Bayes Score: \n')
print("train score:", NB_model.score(Xtrain, Ytrain))
print("test score:", NB_model.score(Xtest, Ytest))
# Out:
# Naive Bayes Score:
#
# train score: 0.9694871794871794
# test score: 0.9593301435406698

# %%
X = tfidf.transform(data_frame['message'])
data_frame['prediction_NB'] = NB_model.predict(X)
report_wrong_predictions('prediction_NB')
# Out:
# Numbers of spams predicted as ham is  187
#
#
# FreeMsg Hey there darling it's been 3 week's now and no word back! I'd like some fun you up for it still? Tb ok! XxX std chgs to send, å£1.50 to rcv
# XXXMobileMovieClub: To use your credit, click the WAP link in the next txt message or click here>> http://wap. xxxmobilemovieclub.com?n=QJKGIGHJJGCBL
# Thanks for your subscription to Ringtone UK your mobile will be charged å£5/month Please confirm by replying YES or NO. If you reply NO you will not be charged
#
#
# Numbers of ham messages predicted as spam is  0

# %% [markdown]
# ### AdaBoostClassifier Algorithm

# %%
ABC_Model = AdaBoostClassifier()
ABC_Model.fit(Xtrain, Ytrain)
print('AdaBoostClassifier Score: \n')
print('train score:', ABC_Model.score(Xtrain,Ytrain))
print('test score:', ABC_Model.score(Xtest, Ytest))
# Out:
# AdaBoostClassifier Score:
#
# train score: 0.9835897435897436
# test score: 0.9730861244019139

# %%
data_frame['prediction_ABC'] = ABC_Model.predict(X)
report_wrong_predictions('prediction_ABC')
# Out:
# Numbers of spams predicted as ham is  95
#
#
# FreeMsg Hey there darling it's been 3 week's now and no word back! I'd like some fun you up for it still? Tb ok! XxX std chgs to send, å£1.50 to rcv
# England v Macedonia - dont miss the goals/team news. Txt ur national team to 87077 eg ENGLAND to 87077 Try:WALES, SCOTLAND 4txt/Ì¼1.20 POBOXox36504W45WQ 16+
# Did you hear about the new \Divorce Barbie\"? It comes with all of Ken's stuff!"
#
#
# Numbers of ham messages predicted as spam is  14
#
#
# He says he'll give me a call when his friend's got the money but that he's definitely buying before the end of the week
# Macha dont feel upset.i can assume your mindset.believe me one evening with me and i have some wonderful plans for both of us.LET LIFE BEGIN AGAIN.call me anytime
# Hey i booked the kb on sat already... what other lessons are we going for ah? Keep your sat night free we need to meet and confirm our lodging

# %% [markdown]
# ### Multi-Layer Perception algorithm

# %%
mlp_classifier_model = MLPClassifier()
mlp_classifier_model.fit(Xtrain, Ytrain)
print('MLP Classifier Score: \n')
print('train score:', mlp_classifier_model.score(Xtrain,Ytrain))
print('test score:', mlp_classifier_model.score(Xtest, Ytest))
# Out:
# MLP Classifier Score:
#
# train score: 1.0
# test score: 0.9868421052631579

# %%
data_frame['prediction_MLP'] = mlp_classifier_model.predict(X)
report_wrong_predictions('prediction_MLP')
# Out:
# Numbers of spams predicted as ham is  21
#
#
# Will u meet ur dream partner soon? Is ur career off 2 a flyng start? 2 find out free, txt HORO followed by ur star sign, e. g. HORO ARIES
# SMS. ac sun0819 posts HELLO:\You seem cool
# Email AlertFrom: Jeri StewartSize: 2KBSubject: Low-cost prescripiton drvgsTo listen to email call 123
#
#
# Numbers of ham messages predicted as spam is  1
#
#
# Mathews or tait or edwards or anderson

# %% [markdown]
# ## Conclusion

# %% [markdown]
# As a conclusion, to compare models with each other, we can look at the scores and wrong predictions.
#
# For Naive-Bayes:
#
# - train score: 0.9705128205128205
# - test score: 0.9545454545454546
#
# For AdaBoostClassifier:
#
# - train score: 0.9846153846153847
# - test score: 0.9736842105263158
#
# For Multi-Layer Perception:
#
# - train score: 1.0
# - test score: 0.9856459330143541
#
# Firstly, look at the scores for the part of the data which is used for training:
#
# - Multi-Layer Perception gives '1.0' score which means 100 percent correct.
#
# - AdaBoostClassifier gives '0.985' score -if we round- which means 98.5 percent correct.
#
# - Naive-Bayes gives '0.971' score -if we round- which means 97.1 percent correct.
#
# Those scores show us how the models are relate to the data which they are trained. This is actually not the most important result but it basicly shows that it might work well with the regular data. Therefore, we expect the score sould be so close to '1.0'. For this the winner is Multi-Layer Perception algorithm.
#
#
# Secondly, look at the scores for actual testing data:
#
# - Multi-Layer Perception gives about '0.986' score which means 98.6 percent correct.
#
# - AdaBoostClassifier gives about '0.974' score which means 97.4 percent correct.
#
# - Naive-Bayes gives about '0.955' score which means 95.5 percent correct.
#
# Those scores show us how the model perform about the data which is not experienced for the models. This is important because in real life usage, model always faces with different data. Therefore, we can't really expect them to score '1.0'. For this part the winner is also Multi-Layer Perception like we assume when we look the training data scores.
#
#
# Finally, when we look at those scores and number of the wrong predictions. Multi-Layer perception is the most successful model. However, for the running time, Multi-Layer Perception works really slow when we compare it with the other two models and those other two are runs with similar times. If we look from this point, the other successful model is AdaBoostClassifier. This depends on the time and processing power you have if you chose one if those three models.
